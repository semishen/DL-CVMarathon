# %% [markdown]
# <a href="https://colab.research.google.com/github/semishen/DL-CVMarathon/blob/master/Day002_change_color_space_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 作業
#
# 使用 [Lena](http://optipng.sourceforge.net/pngtech/img/lena.png)
#
# - 改變圖片的 color space (`HLS`, `LAB`) 並呈現

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('lena.png',cv2.IMREAD_COLOR)
print('image shape: ', img.shape)
print('rgb dtype: ', img.dtype)
# Out:
# image shape:  (512, 512, 3)
# rgb dtype:  uint8

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F91E733EB70>

# %%
# HLS and LAB mode
img_hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
print('hls dtype: ', img_hls.dtype)
img_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
print('lab dtype: ', img_lab.dtype)
cv2_imshow(img_hls)
cv2_imshow(img_lab)
# Out:
# hls dtype:  uint8
# lab dtype:  uint8
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F91E7350F98>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F91E73500F0>
